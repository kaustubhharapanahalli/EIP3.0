# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 300
l = 10
num_filter = 20
# Out:
# Using TensorFlow backend.

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input = Input(shape=(img_height, img_width, channel,))

layer_1 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input)
layer_1 = BatchNormalization(name='norm_1')(layer_1)
layer_1 = LeakyReLU(alpha=0.1)(layer_1)

layer_2 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(layer_1)
layer_2 = BatchNormalization(name='norm_2')(layer_2)
layer_2 = LeakyReLU(alpha=0.1)(layer_2)

layer_3 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(layer_2)
layer_3 = BatchNormalization(name='norm_3')(layer_3)
layer_3 = LeakyReLU(alpha=0.1)(layer_3)

layer_4 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_4', use_bias=False)(layer_3)
layer_4 = BatchNormalization(name='norm_4')(layer_4)
layer_4 = LeakyReLU(alpha=0.1)(layer_4)

layer_5 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(layer_4)
layer_5 = BatchNormalization(name='norm_5')(layer_5)
layer_5 = LeakyReLU(alpha=0.1)(layer_5)
layer_5 = MaxPooling2D(pool_size=(2, 2))(layer_5)

layer_6 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(layer_5)
layer_6 = BatchNormalization(name='norm_6')(layer_6)
layer_6 = LeakyReLU(alpha=0.1)(layer_6)

layer_7 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_7', use_bias=False)(layer_6)
layer_7 = BatchNormalization(name='norm_7')(layer_7)
layer_7 = LeakyReLU(alpha=0.1)(layer_7)

layer_8 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(layer_7)
layer_8 = BatchNormalization(name='norm_8')(layer_8)
layer_8 = LeakyReLU(alpha=0.1)(layer_8)

layer_9 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(layer_8)
layer_9 = BatchNormalization(name='norm_9')(layer_9)
layer_9 = LeakyReLU(alpha=0.1)(layer_9)

layer_10 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_10', use_bias=False)(layer_9)
layer_10 = BatchNormalization(name='norm_10')(layer_10)
layer_10 = LeakyReLU(alpha=0.1)(layer_10)
layer_10 = MaxPooling2D(pool_size=(2, 2))(layer_10)

layer_11 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(layer_10)
layer_11 = BatchNormalization(name='norm_11')(layer_11)
layer_11 = LeakyReLU(alpha=0.1)(layer_11)

layer_12 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_12', use_bias=False)(layer_11)
layer_12 = BatchNormalization(name='norm_12')(layer_12)
layer_12 = LeakyReLU(alpha=0.1)(layer_12)

skip_connection = layer_12

layer_13 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(layer_12)
layer_13 = BatchNormalization(name='norm_13')(layer_13)
layer_13 = LeakyReLU(alpha=0.1)(layer_13)

layer_14 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(layer_13)
layer_14 = BatchNormalization(name='norm_14')(layer_14)
layer_14 = LeakyReLU(alpha=0.1)(layer_14)

layer_15 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_15', use_bias=False)(layer_14)
layer_15 = BatchNormalization(name='norm_15')(layer_15)
layer_15 = LeakyReLU(alpha=0.1)(layer_15)
layer_15 = MaxPooling2D(pool_size=(2, 2))(layer_15)

layer_16 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(layer_15)
layer_16 = BatchNormalization(name='norm_16')(layer_16)
layer_16 = LeakyReLU(alpha=0.1)(layer_16)

layer_17 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_17', use_bias=False)(layer_16)
layer_17 = BatchNormalization(name='norm_17')(layer_17)
layer_17 = LeakyReLU(alpha=0.1)(layer_17)

layer_18 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(layer_17)
layer_18 = BatchNormalization(name='norm_18')(layer_18)
layer_18 = LeakyReLU(alpha=0.1)(layer_18)

layer_19 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(layer_18)
layer_19 = BatchNormalization(name='norm_19')(layer_19)
layer_19 = LeakyReLU(alpha=0.1)(layer_19)

layer_20 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(layer_19)
layer_20 = BatchNormalization(name='norm_20')(layer_20)
layer_20 = LeakyReLU(alpha=0.1)(layer_20)


skip_connection = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

layer_21 = concatenate([skip_connection, layer_20])


layer_22 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(layer_21)
layer_22 = BatchNormalization(name='norm_22')(layer_22)
layer_22 = LeakyReLU(alpha=0.1)(layer_22)


layer_23 = Flatten()(layer_22)

output = Dense(num_classes, activation='softmax')(layer_23)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         input_4[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 32)   128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 32, 32, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 32, 32, 64)   18432       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 32, 32, 64)   256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 32, 32, 64)   0           norm_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 32, 32, 128)  73728       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 32, 32, 128)  512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 32, 32, 128)  0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 32, 32, 256)  294912      leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 32, 32, 256)  1024        conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 32, 32, 256)  0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 32, 32, 512)  1179648     leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 32, 32, 512)  2048        conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 32, 32, 512)  0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0           leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 16, 16, 32)   147456      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 16, 16, 32)   128         conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 16, 16, 32)   0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 16, 16, 64)   18432       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 16, 16, 64)   256         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 16, 16, 64)   0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 16, 16, 128)  73728       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 16, 16, 128)  512         conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 16, 16, 128)  0           norm_8[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 16, 16, 256)  294912      leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 16, 16, 256)  1024        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 16, 16, 256)  0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 16, 16, 512)  1179648     leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 16, 16, 512)  2048        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 16, 16, 512)  0           norm_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 512)    0           leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 8, 8, 32)     147456      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 8, 8, 32)     128         conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 8, 8, 32)     0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 8, 8, 64)     18432       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 8, 8, 64)     256         conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 8, 8, 64)     0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 8, 8, 128)    73728       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 8, 8, 128)    512         conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 8, 8, 128)    0           norm_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 8, 8, 256)    294912      leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 8, 8, 256)    1024        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 8, 8, 256)    0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 8, 8, 512)    1179648     leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 8, 8, 512)    2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 8, 8, 512)    0           norm_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 512)    0           leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 4, 4, 32)     147456      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 4, 4, 32)     128         conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 4, 4, 32)     0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 4, 4, 64)     18432       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 4, 4, 64)     256         conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 4, 4, 64)     0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 4, 4, 128)    73728       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 4, 4, 128)    512         conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 4, 4, 128)    0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 4, 4, 256)    294912      leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 4, 4, 256)    1024        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 8, 8, 128)    8192        leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 4, 4, 256)    0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 8, 8, 128)    512         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 4, 4, 512)    1179648     leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 8, 8, 128)    0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 4, 4, 512)    2048        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4, 4, 512)    0           leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 4, 4, 512)    0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           lambda_1[0][0]
#                                                                  leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 4, 4, 1024)   9437184     concatenate_1[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 4, 4, 1024)   4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 4, 4, 1024)   0           norm_22[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16384)        0           leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           163850      flatten_1[0][0]
# ==================================================================================================
# Total params: 16,339,818
# Trainable params: 16,329,578
# Non-trainable params: 10,240
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=50,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 252s 5ms/step - loss: 2.2879 - acc: 0.2557 - val_loss: 5.1573 - val_acc: 0.1649
# Epoch 2/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 2.2892 - acc: 0.2694 - val_loss: 2.0323 - val_acc: 0.2713
# Epoch 3/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 2.1381 - acc: 0.3044 - val_loss: 1.8913 - val_acc: 0.3314
# Epoch 4/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.8176 - acc: 0.4004 - val_loss: 1.6842 - val_acc: 0.4076
# Epoch 5/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.7905 - acc: 0.4124 - val_loss: 3.0585 - val_acc: 0.2377
# Epoch 6/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.7791 - acc: 0.4173 - val_loss: 1.8848 - val_acc: 0.3938
# Epoch 7/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.5833 - acc: 0.4829 - val_loss: 1.6770 - val_acc: 0.4743
# Epoch 8/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.4265 - acc: 0.5213 - val_loss: 1.3736 - val_acc: 0.5205
# Epoch 9/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.3297 - acc: 0.5524 - val_loss: 1.3571 - val_acc: 0.5217
# Epoch 10/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.5052 - acc: 0.4975 - val_loss: 2.6660 - val_acc: 0.2487
# Epoch 11/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.4102 - acc: 0.5309 - val_loss: 1.8678 - val_acc: 0.4435
# Epoch 12/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.2060 - acc: 0.5991 - val_loss: 1.4154 - val_acc: 0.5346
# Epoch 13/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.0971 - acc: 0.6407 - val_loss: 1.2047 - val_acc: 0.5778
# Epoch 14/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.0482 - acc: 0.6538 - val_loss: 2.1406 - val_acc: 0.5227
# Epoch 15/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.9311 - acc: 0.6972 - val_loss: 0.9867 - val_acc: 0.6550
# Epoch 16/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.1066 - acc: 0.6675 - val_loss: 2.4889 - val_acc: 0.2413
# Epoch 17/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.4117 - acc: 0.5557 - val_loss: 2.7316 - val_acc: 0.2314
# Epoch 18/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 1.1349 - acc: 0.6460 - val_loss: 1.4372 - val_acc: 0.6048
# Epoch 19/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.8985 - acc: 0.7158 - val_loss: 0.9929 - val_acc: 0.6586
# Epoch 20/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.7881 - acc: 0.7519 - val_loss: 4.0293 - val_acc: 0.4583
# Epoch 21/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.9976 - acc: 0.7069 - val_loss: 1.1075 - val_acc: 0.6259
# Epoch 22/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.7568 - acc: 0.7794 - val_loss: 1.1688 - val_acc: 0.6297
# Epoch 23/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.6454 - acc: 0.8145 - val_loss: 1.3629 - val_acc: 0.6358
# Epoch 24/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.5889 - acc: 0.8277 - val_loss: 1.2291 - val_acc: 0.6646
# Epoch 25/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.4471 - acc: 0.8809 - val_loss: 1.2513 - val_acc: 0.6711
# Epoch 26/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.3623 - acc: 0.9042 - val_loss: 1.1889 - val_acc: 0.6795
# Epoch 27/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.3145 - acc: 0.9177 - val_loss: 1.4846 - val_acc: 0.6546
# Epoch 28/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.1458 - acc: 0.9522 - val_loss: 1.4212 - val_acc: 0.6800
# Epoch 29/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0893 - acc: 0.9736 - val_loss: 1.4276 - val_acc: 0.6840
# Epoch 30/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0553 - acc: 0.9874 - val_loss: 1.4595 - val_acc: 0.6866
# Epoch 31/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0405 - acc: 0.9917 - val_loss: 1.5184 - val_acc: 0.6857
# Epoch 32/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0459 - acc: 0.9879 - val_loss: 1.6388 - val_acc: 0.6787
# Epoch 33/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0927 - acc: 0.9684 - val_loss: 1.6994 - val_acc: 0.6762
# Epoch 34/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0701 - acc: 0.9770 - val_loss: 1.6072 - val_acc: 0.6802
# Epoch 35/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0295 - acc: 0.9932 - val_loss: 1.5894 - val_acc: 0.6924
# Epoch 36/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0166 - acc: 0.9970 - val_loss: 1.5735 - val_acc: 0.6968
# Epoch 37/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0169 - acc: 0.9968 - val_loss: 1.8002 - val_acc: 0.6662
# Epoch 38/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.1194 - acc: 0.9595 - val_loss: 2.3281 - val_acc: 0.6291
# Epoch 39/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0707 - acc: 0.9755 - val_loss: 1.6861 - val_acc: 0.6900
# Epoch 40/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0185 - acc: 0.9958 - val_loss: 1.6346 - val_acc: 0.6953
# Epoch 41/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0048 - acc: 0.9998 - val_loss: 1.5901 - val_acc: 0.7034
# Epoch 42/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.5780 - val_acc: 0.7049
# Epoch 43/50
# 50000/50000 [==============================] - 237s 5ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.5880 - val_acc: 0.7066
# Epoch 44/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.6026 - val_acc: 0.7084
# Epoch 45/50
# 50000/50000 [==============================] - 237s 5ms/step - loss: 0.0034 - acc: 0.9993 - val_loss: 1.9593 - val_acc: 0.6726
# Epoch 46/50
# 50000/50000 [==============================] - 236s 5ms/step - loss: 0.2528 - acc: 0.9213 - val_loss: 1.7603 - val_acc: 0.6692
# Epoch 47/50
# 50000/50000 [==============================] - 238s 5ms/step - loss: 0.0255 - acc: 0.9936 - val_loss: 1.5440 - val_acc: 0.7060
# Epoch 48/50
# 50000/50000 [==============================] - 241s 5ms/step - loss: 0.0058 - acc: 0.9997 - val_loss: 1.5383 - val_acc: 0.7065
# Epoch 49/50
# 50000/50000 [==============================] - 241s 5ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 1.5552 - val_acc: 0.7095
# Epoch 50/50
# 50000/50000 [==============================] - 240s 5ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.5697 - val_acc: 0.7116

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 20s 2ms/step
# Test loss: 1.5696963675498963
# Test accuracy: 0.7116
# Saved the model to disk

# %%
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
from google.colab import files

files.download('Yolo_Basic_model2.h5')
